# %%
from tensorflow.keras import models, layers, activations, initializers, utils

# %%
path = './Data'
batch_size = 64

train = utils.image_dataset_from_directory(
    directory=path + '/Train',
    shuffle = True,
    seed = 1,
    image_size = (64,64),
    batch_size = batch_size
)

test = utils.image_dataset_from_directory(
    directory=path + '/Test',
    shuffle = True,
    seed = 1,
    image_size = (64,64),
    batch_size = batch_size
)
# Out:
# Found 50000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.

# %%
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
])

model = models.Sequential([
    layers.Input(shape=(64,64,3)),
    data_augmentation,   
    layers.Rescaling(1./255),

    # Bloco 1
    layers.Conv2D(24, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    
    layers.Conv2D(24, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),

    # Bloco 2
    layers.Conv2D(32, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    
    layers.Conv2D(32, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),

    # Bloco 3
    layers.Conv2D(64, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(64, (3,3), padding='same'),

    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),

    # Bloco 4
    layers.Conv2D(128, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(128, (3,3), padding='same'),

    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),

    layers.GlobalAveragePooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),

    layers.Dense(10, activation='softmax'),
])
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/disrct/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer = optimizers.Adam(
        learning_rate = lr    
    ),
    loss = losses.SparseCategoricalCrossentropy(),
    metrics = [ metrics.sparse_categorical_accuracy ]
)

from tensorflow.keras import callbacks

patience = 5
epochs = 100
model_path = "./model.keras"

model.fit(
    train,
    validation_data = test,
    epochs = epochs,
    verbose = True,
    
    callbacks = [
        callbacks.EarlyStopping(
            monitor = 'val_loss',
            patience = patience,
            verbose = 1
        ),
        callbacks .ModelCheckpoint(
            filepath = model_path,
            save_weights_only = False,
            monitor = 'loss',
            mode = 'min',
            save_best_only = True
        )
    ]
)
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 154s 190ms/step - loss: 1.7345 - sparse_categorical_accuracy: 0.3652 - val_loss: 1.5056 - val_sparse_categorical_accuracy: 0.4454
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 148s 190ms/step - loss: 1.4128 - sparse_categorical_accuracy: 0.4837 - val_loss: 1.2071 - val_sparse_categorical_accuracy: 0.5668
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 145s 185ms/step - loss: 1.2773 - sparse_categorical_accuracy: 0.5415 - val_loss: 1.1859 - val_sparse_categorical_accuracy: 0.5920
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 146s 186ms/step - loss: 1.1735 - sparse_categorical_accuracy: 0.5855 - val_loss: 0.9983 - val_sparse_categorical_accuracy: 0.6523
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 146s 186ms/step - loss: 1.0963 - sparse_categorical_accuracy: 0.6125 - val_loss: 0.9040 - val_sparse_categorical_accuracy: 0.6916
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 152s 194ms/step - loss: 1.0316 - sparse_categorical_accuracy: 0.6404 - val_loss: 0.8559 - val_sparse_categorical_accuracy: 0.7077
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 148s 189ms/step - loss: 0.9935 - sparse_categorical_accuracy: 0.6552 - val_loss: 0.8241 - val_sparse_categorical_accuracy: 0.7255
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 149s 190ms/step - loss: 0.9492 - sparse_categorical_accuracy: 0.6697 - val_loss: 0.7387 - val_sparse_categorical_accuracy: 0.7452
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 146s 186ms/step - loss: 0.9111 - sparse_categorical_accuracy: 0.6878 - val_loss: 0.7617 - val_sparse_categorical_accuracy: 0.7398
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 146s 187ms/step - loss: 0.8666 - sparse_categorical_accuracy: 0.7042 - val_loss: 0.7392 - val_sparse_categorical_accuracy: 0.7522
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 148s 189ms/step - loss: 0.8196 - sparse_categorical_accuracy: 0.7236 - val_loss: 0.7632 - val_sparse_categorical_accuracy: 0.7500
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 151s 193ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.7324 - val_loss: 0.6285 - val_sparse_categorical_accuracy: 0.7880
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 147s 188ms/step - loss: 0.7650 - sparse_categorical_accuracy: 0.7435 - val_loss: 0.6664 - val_sparse_categorical_accuracy: 0.7795
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 200ms/step - loss: 0.7383 - sparse_categorical_accuracy: 0.7537 - val_loss: 0.7197 - val_sparse_categorical_accuracy: 0.7679
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 199ms/step - loss: 0.7066 - sparse_categorical_accuracy: 0.7656 - val_loss: 0.5852 - val_sparse_categorical_accuracy: 0.8034
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 204ms/step - loss: 0.6827 - sparse_categorical_accuracy: 0.7712 - val_loss: 0.6151 - val_sparse_categorical_accuracy: 0.7987
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 162s 208ms/step - loss: 0.6595 - sparse_categorical_accuracy: 0.7791 - val_loss: 0.5660 - val_sparse_categorical_accuracy: 0.8145
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 161s 206ms/step - loss: 0.6323 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.5947 - val_sparse_categorical_accuracy: 0.8036
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 219ms/step - loss: 0.6167 - sparse_categorical_accuracy: 0.8003 - val_loss: 0.5660 - val_sparse_categorical_accuracy: 0.8105
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 219ms/step - loss: 0.5937 - sparse_categorical_accuracy: 0.8025 - val_loss: 0.6053 - val_sparse_categorical_accuracy: 0.8033
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 166s 213ms/step - loss: 0.5785 - sparse_categorical_accuracy: 0.8092 - val_loss: 0.5762 - val_sparse_categorical_accuracy: 0.8094
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 199ms/step - loss: 0.5543 - sparse_categorical_accuracy: 0.8165 - val_loss: 0.5590 - val_sparse_categorical_accuracy: 0.8233
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 199ms/step - loss: 0.5491 - sparse_categorical_accuracy: 0.8166 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.8082
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 153s 196ms/step - loss: 0.5338 - sparse_categorical_accuracy: 0.8242 - val_loss: 0.5119 - val_sparse_categorical_accuracy: 0.8288
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 151s 193ms/step - loss: 0.5178 - sparse_categorical_accuracy: 0.8287 - val_loss: 0.5646 - val_sparse_categorical_accuracy: 0.8172
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 151s 193ms/step - loss: 0.5121 - sparse_categorical_accuracy: 0.8306 - val_loss: 0.4881 - val_sparse_categorical_accuracy: 0.8385
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 152s 195ms/step - loss: 0.4965 - sparse_categorical_accuracy: 0.8371 - val_loss: 0.4939 - val_sparse_categorical_accuracy: 0.8391
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 150s 191ms/step - loss: 0.4907 - sparse_categorical_accuracy: 0.8366 - val_loss: 0.4442 - val_sparse_categorical_accuracy: 0.8482
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 150s 192ms/step - loss: 0.4813 - sparse_categorical_accuracy: 0.8394 - val_loss: 0.4498 - val_sparse_categorical_accuracy: 0.8525
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 145s 186ms/step - loss: 0.4788 - sparse_categorical_accuracy: 0.8417 - val_loss: 0.4719 - val_sparse_categorical_accuracy: 0.8466
# Epoch 31/100
# 389/782 ━━━━━━━━━━━━━━━━━━━━ 1:16 195ms/step - loss: 0.4745 - sparse_categorical_accuracy: 0.8430
